# %% [markdown]
# # 01 - Data Exploration
# Explore the raw synthetic sales dataset before cleaning.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/sales_raw.csv')
df.shape

# %%
df.head()

# %%
df.dtypes

# %%
df.isna().sum()

# %%
df['category'].value_counts(dropna=False)

# %%
df.duplicated().sum()
