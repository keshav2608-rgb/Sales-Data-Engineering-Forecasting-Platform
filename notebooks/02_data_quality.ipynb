# %% [markdown]
# # 02 - Data Quality
# Run the project's quality checks and inspect the report.

# %%
import sys; sys.path.insert(0, '..')
from pipeline.extract import extract
from pipeline.quality_checks import run_quality_checks, print_quality_report

# %%
raw = extract()
report = run_quality_checks(raw)
print_quality_report(report)

# %%
from pipeline.transform import clean
cleaned = clean(raw)
print(len(raw), '->', len(cleaned))
